# %% [markdown]
# # Iris Dataset

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
sns.set()

# %% [markdown]
# ## load the dataset

# %%
data=pd.read_csv("15453055-iris-dataset.csv")
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
data.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# dtype: int64

# %% [markdown]
# ## Plot the data

# %%
plt.scatter(x=data["petal_length"],y=data["petal_width"])
plt.xlabel("Petal Lenght")
plt.ylabel("Petal Width")
# Out:
# Text(0, 0.5, 'Petal Width')

# %% [markdown]
# ## Standardising the x data

# %%
from sklearn import preprocessing
data_scaled=preprocessing.scale(data)
data_scaled
# Out:
# array([[-9.00681170e-01,  1.03205722e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00, -1.24957601e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.38535265e+00,  3.37848329e-01, -1.39813811e+00,
#         -1.31297673e+00],
#        [-1.50652052e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.02184904e+00,  1.26346019e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-5.37177559e-01,  1.95766909e+00, -1.17067529e+00,
#         -1.05003079e+00],
#        [-1.50652052e+00,  8.00654259e-01, -1.34127240e+00,
#         -1.18150376e+00],
#        [-1.02184904e+00,  8.00654259e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.74885626e+00, -3.56360566e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.44444970e+00],
#        [-5.37177559e-01,  1.49486315e+00, -1.28440670e+00,
#         -1.31297673e+00],
# ...

# %%
test=data_scaled[:,2:4]
test
# Out:
# array([[-1.34127240e+00, -1.31297673e+00],
#        [-1.34127240e+00, -1.31297673e+00],
#        [-1.39813811e+00, -1.31297673e+00],
#        [-1.28440670e+00, -1.31297673e+00],
#        [-1.34127240e+00, -1.31297673e+00],
#        [-1.17067529e+00, -1.05003079e+00],
#        [-1.34127240e+00, -1.18150376e+00],
#        [-1.28440670e+00, -1.31297673e+00],
#        [-1.34127240e+00, -1.31297673e+00],
#        [-1.28440670e+00, -1.44444970e+00],
#        [-1.28440670e+00, -1.31297673e+00],
#        [-1.22754100e+00, -1.31297673e+00],
#        [-1.34127240e+00, -1.44444970e+00],
#        [-1.51186952e+00, -1.44444970e+00],
#        [-1.45500381e+00, -1.31297673e+00],
#        [-1.28440670e+00, -1.05003079e+00],
#        [-1.39813811e+00, -1.05003079e+00],
#        [-1.34127240e+00, -1.18150376e+00],
#        [-1.17067529e+00, -1.18150376e+00],
#        [-1.28440670e+00, -1.18150376e+00],
#        [-1.17067529e+00, -1.31297673e+00],
#        [-1.28440670e+00, -1.05003079e+00],
# ...

# %% [markdown]
# ## Use elbow method

# %%
wcss=[]
for i in range(1,10):
    kmeans_temp=KMeans(i)
    kmeans_temp.fit(test)
    wcss_temp=kmeans_temp.fit_predict(test)
    wcss.append(kmeans_temp.inertia_)
# Out:
# C:\Users\Magesh\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Magesh\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Magesh\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Magesh\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
plt.plot(range(1,10),wcss)
plt.xlabel("Clusters")
plt.ylabel("WCSS")
# Out:
# Text(0, 0.5, 'WCSS')

# %% [markdown]
# Here 3 seems to be a better cluster value

# %%
kmeans_new=KMeans(3)
kmeans_new.fit(test)
clusters=kmeans_new.fit_predict(test)
# Out:
# C:\Users\Magesh\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Magesh\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
df=pd.DataFrame(test)
df=df.rename(columns={0:"Pedal Length",1:"Pedal Width"})
df
# Out:
#      Pedal Length  Pedal Width
# 0       -1.341272    -1.312977
# 1       -1.341272    -1.312977
# 2       -1.398138    -1.312977
# 3       -1.284407    -1.312977
# 4       -1.341272    -1.312977
# ..            ...          ...
# 145      0.819624     1.447956
# 146      0.705893     0.922064
# 147      0.819624     1.053537
# 148      0.933356     1.447956
# 149      0.762759     0.790591
#
# [150 rows x 2 columns]

# %%
df["Clusters"]=clusters
df
# Out:
#      Pedal Length  Pedal Width  Clusters
# 0       -1.341272    -1.312977         0
# 1       -1.341272    -1.312977         0
# 2       -1.398138    -1.312977         0
# 3       -1.284407    -1.312977         0
# 4       -1.341272    -1.312977         0
# ..            ...          ...       ...
# 145      0.819624     1.447956         2
# 146      0.705893     0.922064         2
# 147      0.819624     1.053537         2
# 148      0.933356     1.447956         2
# 149      0.762759     0.790591         2
#
# [150 rows x 3 columns]

# %% [markdown]
# ## Plot the data

# %%
plt.scatter(x=df["Pedal Length"],y=df["Pedal Width"],c=df["Clusters"],cmap="rainbow")
plt.xlabel("Pedal Length")
plt.ylabel("Pedal Width")
# Out:
# Text(0, 0.5, 'Pedal Width')

# %% [markdown]
# Thus we have found 3 clusters
